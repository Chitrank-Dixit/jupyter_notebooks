# %%
# for making data compatible for analysis
import pandas as pd
import numpy as np

# for visualizing
import matplotlib.pyplot as plt
# %matplotlib inline


# for visualizing
import seaborn as sns

# This will bring all the data of the wines sold in italy (normalized data)
data = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data", header=None)
data.columns = ["V"+str(i) for i in range(1, len(data.columns)+1)]  # rename column names to be similar to R naming convention
data.V1 = data.V1.astype(str)
X = data.loc[:, "V2":]  # independent variables data
y = data.V1  # dependednt variable data
data
# Out:
#     V1     V2    V3    V4    V5   V6    V7    V8    V9   V10        V11   V12  \
# 0    1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29   5.640000  1.04
# 1    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.380000  1.05
# 2    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.680000  1.03
# 3    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.800000  0.86
# 4    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.320000  1.04
# 5    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.750000  1.05
# 6    1  14.39  1.87  2.45  14.6   96  2.50  2.52  0.30  1.98   5.250000  1.02
# 7    1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25   5.050000  1.06
# 8    1  14.83  1.64  2.17  14.0   97  2.80  2.98  0.29  1.98   5.200000  1.08
# 9    1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85   7.220000  1.01
# 10   1  14.10  2.16  2.30  18.0  105  2.95  3.32  0.22  2.38   5.750000  1.25
# ...

# %%
pd.tools.plotting.scatter_matrix(data.loc[:, "V2":"V6"], diagonal="kde")
plt.tight_layout()
plt.show()

# %%
pd.tools.plotting.scatter_matrix(data.loc[:, "V7":"V11"], diagonal="kde")
plt.tight_layout()
plt.show()

# %%
pd.tools.plotting.scatter_matrix(data.loc[:, "V12":"V14"], diagonal="kde")
plt.tight_layout()
plt.show()

# %%
# using profile plot to visualize the multivariate data

ax = data[["V1","V2","V3","V4","V5","V6", "V7", "V8", "V9", "V10", "V11", "V12", "V13"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# one more way of plotting the variables

sns.lmplot("V4", "V5", data, hue="V1", fit_reg=False);

# %%
# the mean distribution
X.apply(np.mean)
# Out:
# V2      13.000618
# V3       2.336348
# V4       2.366517
# V5      19.494944
# V6      99.741573
# V7       2.295112
# V8       2.029270
# V9       0.361854
# V10      1.590899
# V11      5.058090
# V12      0.957449
# V13      2.611685
# V14    746.893258
# dtype: float64

# %%
# the standard deviation distribution
X.apply(np.std)
# Out:
# V2       0.809543
# V3       1.114004
# V4       0.273572
# V5       3.330170
# V6      14.242308
# V7       0.624091
# V8       0.996049
# V9       0.124103
# V10      0.570749
# V11      2.311765
# V12      0.227929
# V13      0.707993
# V14    314.021657
# dtype: float64

# %%
class2data = data[y=="2"]
class2data.loc[:, "V2":].apply(np.mean)
# Out:
# V2      12.278732
# V3       1.932676
# V4       2.244789
# V5      20.238028
# V6      94.549296
# V7       2.258873
# V8       2.080845
# V9       0.363662
# V10      1.630282
# V11      3.086620
# V12      1.056282
# V13      2.785352
# V14    519.507042
# dtype: float64

# %%
class2data.loc[:, "V2":].apply(np.std)
# Out:
# V2       0.534162
# V3       1.008391
# V4       0.313238
# V5       3.326097
# V6      16.635097
# V7       0.541507
# V8       0.700713
# V9       0.123085
# V10      0.597813
# V11      0.918393
# V12      0.201503
# V13      0.493064
# V14    156.100173
# dtype: float64

# %%
def printMeanAndSdByGroup(variables, groupvariable):
    data_groupby = variables.groupby(groupvariable)
    print("## Means:")
    print(data_groupby.apply(np.mean))
    print("\n## Standard deviations:")
    print(data_groupby.apply(np.std))
    print("\n## Sample sizes:")
    print(pd.DataFrame(data_groupby.apply(len)))
    
printMeanAndSdByGroup(X, y)
# Out:
# ## Means:
#            V2        V3        V4         V5          V6        V7        V8  \
# V1
# 1   13.744746  2.010678  2.455593  17.037288  106.338983  2.840169  2.982373
# 2   12.278732  1.932676  2.244789  20.238028   94.549296  2.258873  2.080845
# 3   13.153750  3.333750  2.437083  21.416667   99.312500  1.678750  0.781458
#
#           V9       V10       V11       V12       V13          V14
# V1
# 1   0.290000  1.899322  5.528305  1.062034  3.157797  1115.711864
# 2   0.363662  1.630282  3.086620  1.056282  2.785352   519.507042
# 3   0.447500  1.153542  7.396250  0.682708  1.683542   629.895833
#
# ## Standard deviations:
#           V2        V3        V4        V5         V6        V7        V8  \
# V1
# 1   0.458192  0.682689  0.225233  2.524651  10.409595  0.336077  0.394111
# 2   0.534162  1.008391  0.313238  3.326097  16.635097  0.541507  0.700713
# 3   0.524689  1.076514  0.182756  2.234515  10.776433  0.353233  0.290431
#
# ...

# %%
a = [" sdfsdf", " sdfsdf", " sdfsdf"].strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-125c27497e50> in <module>()
# ----> 1 a = [" sdfsdf", " sdfsdf", " sdfsdf"].strip()
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
from datetime import date

d0 = date(2017, 9, 30)
d1 = date(2017, 4, 16)
delta = d0 - d1
print delta.days


# books

hp2 = 16
hp3 = 22
hp4 = 37
hp5 = 38
hp6 = 30
hp7 = 36

float(hp2+ hp3+ hp4+ hp5+ hp6+ hp7) / float(delta.days)
# Out:
# 167
# 1.0718562874251496

# %%
a = ["Gown", "Lehenga", "Anarkali"]
sorted(a)
# Out:
# ['Anarkali', 'Gown', 'Lehenga']
