# %%
# %%bash
#
# cat parent_item_recommendation_data.json
# Out:
# [{"rental": 1499, "product_tags": "New-Reserve, Spring Wedding, Under 1999 store, The diwali dress code, Under 2999 - Women's Ethnic, women ethnic reserve", "inventory_category": "Lehenga", "brand": "6Y COLLECTIVE", "inventory_item": [{"placed": 25, "confirm + returned": 15, "confirm": 13, "inventory_item_id": "FRES01887-L-3777"}], "parent_id": "FRES01887", "characteristic_details": [{"name": "Lehenga Flare", "characteristics": ["big flare"]}, {"name": "Type of embroidery", "characteristics": ["Machine Embroidery"]}, {"name": "Fabric", "characteristics": ["Dupion Silk", "Georgette"]}, {"name": "Color of embroidery", "characteristics": ["Light Gold Embroidery"]}, {"name": "Shoulder", "characteristics": ["Normal Shoulder"]}, {"name": "Neckline", "characteristics": ["Round neckline"]}, {"name": "Choli Silhouette", "characteristics": ["Ends at upper waist (Short blouse)"]}, {"name": "Embroidery", "characteristics": ["Mirror/Abla Work"]}, {"name": "Sleeves", "characteristics": ["Short/ Cap / Half Sleeve"]}]}, {"rental": 2899, "product_tags": "Bridesmaid, Designer Spotlight Surendri, Teej Special, The bridesmaid guide, Cocktail Ready, Best Friend's Wedding, Bridesmaids Wedding Guide, Best of 2016 Womens, SANGEET, Under 2999 - Women's Ethnic, women ethnic reserve", "inventory_category": "Lehenga", "brand": "SURENDRI", "inventory_item": [{"placed": 25, "confirm + returned": 9, "confirm": 6, "inventory_item_id": "FRES01514-M-3368"}], "parent_id": "FRES01514", "characteristic_details": [{"name": "Lehenga Flare", "characteristics": ["big flare"]}, {"name": "Type of embroidery", "characteristics": ["Machine Embroidery"]}, {"name": "Sleeves", "characteristics": ["Three Quarter Sleeve"]}, {"name": "Fabric", "characteristics": ["Net", "Brocade", "Silk /Silk Blend"]}, {"name": "Lehenga Cut", "characteristics": ["Pleated/Gathered Lehenga"]}, {"name": "Neckline", "characteristics": ["V neckline"]}, {"name": "Shoulder", "characteristics": ["Normal Shoulder"]}, {"name": "Choli Silhouette", "characteristics": ["Ends at upper waist (Short blouse)"]}, {"name": "Embroidery", "characteristics": ["Thread Embroidery"]}]}, {"rental": 1499, "product_tags": "Under 1999 store, Bridesmaid, New Reserve 24 june, Navratri Edit, Bridesmaids Wedding Guide, Under 2999 - Women's Ethnic, women ethnic reserve", "inventory_category": "Lehenga", "brand": "HOUSE OF OMBRE", "inventory_item": [{"placed": 24, "confirm + returned": 10, "confirm": 8, "inventory_item_id": "FRES01964-L-3861"}], "parent_id": "FRES01964", "characteristic_details": [{"name": "Sleeves", "characteristics": ["Sleeveless"]}, {"name": "Fabric", "characteristics": ["Net", "Brocade"]}, {"name": "Choli embroidery", "characteristics": ["CHoli Placement Embroidery"]}, {"name": "Neckline", "characteristics": ["Round neckline"]}, {"name": "Choli Silhouette", "characteristics": ["Jacket/ Kurta Length Blouse"]}, {"name": "Aesthetic", "characteristics": ["Traditional heavy Style"]}, {"name": "Type of embroidery", "characteristics": ["Hand Embroidery"]}, {"name": "Lehenga Cut", "characteristics": ["Kalidaar Lehenga"]}, {"name": "Shoulder", "characteristics": ["Normal Shoulder"]}, {"name": "Embroidery", "characteristics": ["Mirror/Abla Work"]}, {"name": "Choli button", "characteristics": ["Side Zipper Blouse"]}]}, {"rental": 4899, "product_tags": "The Perfect Bride, New Reserve 24 june, New September Reserve, Wedding trends, The NRI bride edit, Best of 2016 Womens, women ethnic reserve", "inventory_category": "Lehenga", "brand": "PRATHYUSHA GARIMELLA", "inventory_item": [{"placed": 23, "confirm + returned": 7, "confirm": 7, "inventory_item_id": "FRES02458-M-5376"}], "parent_id": "FRES02458", "characteristic_details": [{"name": "Lehenga Flare", "characteristics": ["big flare"]}, {"name": "Type of embroidery", "characteristics": ["Machine And Hand Embroidery"]}, {"name": "Embroidery", "characteristics": ["Sequin embroidered", "Thread Embroidery"]}, {"name": "Aesthetic", "characteristics": ["Contemporary style"]}, { ...

# %%
# extracing data from ijson

import json

filename = 'parent_item_recommendation_data.json'

list_of_columns = [
    "rental",
    "product_tags",
    "inventory_category",
    "brand",
    "characteristic_details",
    "parent_id",
    "inventory_item"
]

with open(filename, 'r') as data_file:
    data = json.load(data_file)
    
print data
import pandas as pd
stops = pd.DataFrame(data, columns=list_of_columns)
